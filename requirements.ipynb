# %%
'''
import tensorflow as tf

print(tf.__version__)
# 1.14.0

tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)
# True
'''
# How to check if the code is running on GPU or CPU?

from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5160395475122885519
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7123860991706729433
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14301131288914642341
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
# pip install tensorflow-gpu==1.14.0
pip install tensorflow-gpu==1.14.0
# Out:
# Collecting tensorflow-gpu==1.14.0
#   Using cached tensorflow_gpu-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (377.1 MB)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.28.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: gast>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (0.2.2)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (0.8.1)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.18.4)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.12.1)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (3.11.4)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (0.34.2)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (1.0.8)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow-gpu==1.14.0) (0.2.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow-gpu==1.14.0) (46.2.0.post20200511)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.2.2)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.1.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# Collecting absl-py==0.1.12
#   Downloading absl-py-0.1.12.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 3.9 MB/s eta 0:00:011
# Collecting appnope==0.1.0
#   Downloading appnope-0.1.0-py2.py3-none-any.whl (4.0 kB)
# Collecting astor==0.6.2
#   Downloading astor-0.6.2-py2.py3-none-any.whl (26 kB)
# Collecting bleach==1.5.0
#   Downloading bleach-1.5.0-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: cycler==0.10.0 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (0.10.0)
# Collecting decorator==4.2.1
#   Downloading decorator-4.2.1-py2.py3-none-any.whl (9.3 kB)
# Collecting gast==0.2.0
#   Downloading gast-0.2.0.tar.gz (9.4 kB)
# Collecting graphviz==0.8.2
#   Downloading graphviz-0.8.2-py2.py3-none-any.whl (18 kB)
# Collecting grpcio==1.10.0
#   Downloading grpcio-1.10.0.tar.gz (14.0 MB)
#      |████████████████████████████████| 14.0 MB 11.0 MB/s eta 0:00:01
# Collecting h5py==2.7.1
#   Downloading h5py-2.7.1.tar.gz (264 kB)
#      |████████████████████████████████| 264 kB 54.9 MB/s eta 0:00:01
# Collecting html5lib==0.9999999
#   Downloading html5lib-0.9999999.tar.gz (889 kB)
#      |████████████████████████████████| 889 kB 42.7 MB/s eta 0:00:01
# Collecting ipykernel==4.8.2
#   Downloading ipykernel-4.8.2-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 59.5 MB/s eta 0:00:01
# Collecting IPython==7.9.0
#   Downloading ipython-7.9.0-py3-none-any.whl (775 kB)
#      |████████████████████████████████| 775 kB 84.1 MB/s eta 0:00:01
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 14)) (0.2.0)
# Collecting jedi==0.11.1
#   Downloading jedi-0.11.1-py2.py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 57.2 MB/s eta 0:00:01
# Collecting jupyter-client==5.2.3
#   Downloading jupyter_client-5.2.3-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 9.1 MB/s  eta 0:00:01
# Collecting jupyter-core==4.4.0
#   Downloading jupyter_core-4.4.0-py2.py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 55.9 MB/s eta 0:00:01
# Requirement already satisfied: keras==2.3.1 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 18)) (2.3.1)
# Collecting kiwisolver==1.0.1
#   Downloading kiwisolver-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (89 kB)
#      |████████████████████████████████| 89 kB 9.8 MB/s  eta 0:00:01
# Collecting Markdown==2.6.11
#   Downloading Markdown-2.6.11-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.9 MB/s  eta 0:00:01
# Collecting matplotlib==3.1.2
#   Downloading matplotlib-3.1.2-cp37-cp37m-manylinux1_x86_64.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 59.3 MB/s eta 0:00:01
# Collecting numpy==1.14.2
#   Downloading numpy-1.14.2.zip (4.9 MB)
#      |████████████████████████████████| 4.9 MB 48.5 MB/s eta 0:00:01
# Collecting parso==0.1.1
#   Downloading parso-0.1.1-py2.py3-none-any.whl (91 kB)
#      |████████████████████████████████| 91 kB 11.7 MB/s eta 0:00:01
# Collecting pexpect==4.4.0
#   Downloading pexpect-4.4.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 6.2 MB/s  eta 0:00:01
# Collecting pickleshare==0.7.4
#   Downloading pickleshare-0.7.4-py2.py3-none-any.whl (6.9 kB)
# Collecting prompt-toolkit==1.0.15
#   Downloading prompt_toolkit-1.0.15-py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 40.3 MB/s eta 0:00:01
# Collecting protobuf==3.5.2.post1
#   Downloading protobuf-3.5.2.post1-py2.py3-none-any.whl (388 kB)
#      |████████████████████████████████| 388 kB 72.8 MB/s eta 0:00:01
# Collecting ptyprocess==0.5.2
#   Downloading ptyprocess-0.5.2-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: pydot==1.4.1 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 29)) (1.4.1)
# Collecting pydot-ng==1.0.0
#   Downloading pydot_ng-1.0.0.tar.gz (24 kB)
# Collecting Pygments==2.2.0
#   Downloading Pygments-2.2.0-py2.py3-none-any.whl (841 kB)
#      |████████████████████████████████| 841 kB 55.9 MB/s eta 0:00:01
# Collecting pyparsing==2.2.0
#   Downloading pyparsing-2.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.2 MB/s  eta 0:00:01
# Collecting python-dateutil==2.7.1
#   Downloading python_dateutil-2.7.1-py2.py3-none-any.whl (212 kB)
#      |████████████████████████████████| 212 kB 77.0 MB/s eta 0:00:01
# Collecting pytz==2018.3
#   Downloading pytz-2018.3-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 63.5 MB/s eta 0:00:01
# Collecting PyYAML==3.12
#   Downloading PyYAML-3.12.tar.gz (253 kB)
#      |████████████████████████████████| 253 kB 74.7 MB/s eta 0:00:01
# Collecting pyzmq==17.0.0
#   Downloading pyzmq-17.0.0-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 63.7 MB/s eta 0:00:01
# Collecting scipy==1.0.1
#   Downloading scipy-1.0.1.tar.gz (15.5 MB)
#      |████████████████████████████████| 15.5 MB 22.6 MB/s eta 0:00:01
# Requirement already satisfied: simplegeneric==0.8.1 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 38)) (0.8.1)
# Collecting six==1.11.0
#   Downloading six-1.11.0-py2.py3-none-any.whl (10 kB)
# Collecting tensorboard==1.6.0
#   Downloading tensorboard-1.6.0-py3-none-any.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 85.7 MB/s eta 0:00:01
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.4.0 (from -r requirements.txt (line 41)) (from versions: 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 1.15.2, 1.15.3, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0, 2.0.1, 2.0.2, 2.1.0rc0, 2.1.0rc1, 2.1.0rc2, 2.1.0, 2.1.1, 2.2.0rc0, 2.2.0rc1, 2.2.0rc2, 2.2.0rc3, 2.2.0rc4, 2.2.0)
# ERROR: No matching distribution found for tensorflow==1.4.0 (from -r requirements.txt (line 41))
# Note: you may need to restart the kernel to use updated packages.
